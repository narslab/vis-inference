# %%
from PIL import Image # used for loading images
import numpy as np
import os # used for navigating to image path
import imageio # used for writing images
import re # for matching image file name classes
import random

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# source: https://thispointer.com/python-how-to-get-list-of-files-in-directory-and-sub-directories/
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %% [markdown]
# Here, we read in all the image files from the raw image folder ("Pictures for AI") and then sequentially number then into two groups: "Improbable" and "Probable".

# %%
raw_image_dir = '../../data/raw/Pictures for AI'
image_file_list = getListOfFiles(raw_image_dir)

# %%
for filename in image_file_list:
    if '.JPG' in filename or '.jpg' in filename:        
        pass
    else:
        print(filename)
# Out:
# ../../data/raw/Pictures for AI/Site 42/Site 42_Infrastructure.docx
# ../../data/raw/Pictures for AI/Site 67/Site 47_Infrastructure.docx
# ../../data/raw/Pictures for AI/Site 41/Site 41_Infrastructure.docx

# %%
probable_counter = 1
improbable_counter = 1
tidy_image_dir = '../../data/tidy/labeled_images/'
if not os.path.exists(tidy_image_dir):
    os.makedirs(tidy_image_dir)
for filename in image_file_list:
    if '.JPG' in filename or '.jpg' in filename:        
        if any(re.findall(r'improbable', filename, re.IGNORECASE)):
            save_name = tidy_image_dir + 'improbable' + '-' + str(improbable_counter) + '.jpg'
            improbable_counter += 1
        elif any(re.findall(r'probable|possible', filename, re.IGNORECASE)):
            save_name = tidy_image_dir + 'probable' + '-' + str(probable_counter) + '.jpg'
            probable_counter += 1   
        imageio.imwrite(save_name, np.array(Image.open(filename)))
print('Number of probable images saved:', probable_counter-1)
print('Number of improbable images saved:', improbable_counter-1)
# Out:
# Number of probable images saved: 103
# Number of improbable images saved: 259

# %%
def label_img(name):
  word_label = name.split('-')[0]
  if word_label == 'probable' : 
        return np.array([1, 0])
  elif word_label == 'improbable' : 
    return np.array([0, 1])

# %%
random.sample(image_file_list, int(.8*len(image_file_list)))
# Out:
# ['../../data/raw/Pictures for AI/Site 128/Possible (multi stem codominant union at line height).JPG',
#  '../../data/raw/Pictures for AI/Site 72/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 52/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 44/IMG-4283.JPG',
#  '../../data/raw/Pictures for AI/Site 29/Probable (deadwood above line hieght, vine).JPG',
#  '../../data/raw/Pictures for AI/Site 22/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 48/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 136/Possible (low codominant stem).JPG',
#  '../../data/raw/Pictures for AI/Site 112/Possible (3 codominant stems with low crotch, included bark).JPG',
#  '../../data/raw/Pictures for AI/Site 14/8 - Possible(dead limbs, bad angles, topped).JPG',
#  '../../data/raw/Pictures for AI/Site 1/Improbable 3.JPG',
#  '../../data/raw/Pictures for AI/Site 179/10 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 155/Improbable (umbrella pine).JPG',
#  '../../data/raw/Pictures for AI/Site 41/(small right tree has crack all the way thru 4ft, probable) (lg left tree possible, steep attachment).JPG',
#  '../../data/raw/Pictures for AI/Site 75/Probable (significant dieback, decay, defects line side of tree).JPG',
#  '../../data/raw/Pictures for AI/Site 20/6 - Improbable (eastern red cedar 2).JPG',
#  '../../data/raw/Pictures for AI/Site 40/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 53/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 44/IMG-4286.JPG',
#  '../../data/raw/Pictures for AI/Site 9/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 6/Improbable_2.JPG',
#  '../../data/raw/Pictures for AI/Site 41/Probable (dead overhangs).JPG',
#  '../../data/raw/Pictures for AI/Site 34/Improbable (scarlet oak).JPG',
#  '../../data/raw/Pictures for AI/Site 20/7 - Improbable (black cherry).JPG',
#  '../../data/raw/Pictures for AI/Site 163/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 167/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 7/Improbable (linden).JPG',
#  '../../data/raw/Pictures for AI/Site 28/Possible (low codominant stem, reaction wood present).JPG',
#  '../../data/raw/Pictures for AI/Site 178/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 48/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 40/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 113/7 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 161/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 46/3 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 149/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 41/Site 41_Infrastructure.docx',
#  '../../data/raw/Pictures for AI/Site 118/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 179/2 - Probable (standing dead).JPG',
#  '../../data/raw/Pictures for AI/Site 25/Probable(butt rot, large dead limbs).JPG',
#  '../../data/raw/Pictures for AI/Site 113/1 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 76/Probable (dead overhang).JPG',
#  '../../data/raw/Pictures for AI/Site 48/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 83/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 11/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 61/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 60/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 70/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 43/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 112/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 162/Probable (large crack from base, deadwood).JPG',
#  '../../data/raw/Pictures for AI/Site 61/IMG-4268.JPG',
#  '../../data/raw/Pictures for AI/Site 128/Possible (dead limbs).JPG',
#  '../../data/raw/Pictures for AI/Site 15/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 28/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 167/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 77/Improbable.jpg',
#  '../../data/raw/Pictures for AI/Site 149/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 16/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 150/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 23/Improbable_2_london plane.JPG',
#  '../../data/raw/Pictures for AI/Site 152/Possible (dead overhangs).JPG',
#  '../../data/raw/Pictures for AI/Site 179/12 - Probable (crabapple, mostly dead, vine strangled).JPG',
#  '../../data/raw/Pictures for AI/Site 155/Improbable (red oak).JPG',
#  '../../data/raw/Pictures for AI/Site 97/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 138/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 70/Improbable (6).JPG',
#  '../../data/raw/Pictures for AI/Site 138/Possible (low crotch codominant stem).JPG',
#  '../../data/raw/Pictures for AI/Site 46/7 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 176/Improbable (beech).jpg',
#  '../../data/raw/Pictures for AI/Site 51/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 65/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 48/Probable (dead overhang).JPG',
#  '../../data/raw/Pictures for AI/Site 179/3 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 113/4 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 44/IMG-4285.JPG',
#  '../../data/raw/Pictures for AI/Site 167/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 53/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 29/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 158/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 22/Possible (dead limbs poor attachment angle).JPG',
#  '../../data/raw/Pictures for AI/Site 158/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 182/Improbable (6).JPG',
#  '../../data/raw/Pictures for AI/Site 44/IMG-4287.JPG',
#  '../../data/raw/Pictures for AI/Site 97/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 90/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 163/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 113/5 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 84/Possible (decay on trunk).JPG',
#  '../../data/raw/Pictures for AI/Site 61/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 72/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 148/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 81/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 65/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 63/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 167/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 162/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 29/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 31/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 81/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 58/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 71/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 104/Probable (deadwood).JPG',
#  '../../data/raw/Pictures for AI/Site 104/(Probable, deadwood, dieback, large wound street side).JPG',
#  '../../data/raw/Pictures for AI/Site 10/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 40/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 14/4 - Probable(standing dead).JPG',
#  '../../data/raw/Pictures for AI/Site 6/Improbable_7.JPG',
#  '../../data/raw/Pictures for AI/Site 67/Possible (past failures, large wound, weak attachment).JPG',
#  '../../data/raw/Pictures for AI/Site 52/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 176/Improbable (hemlock).jpg',
#  '../../data/raw/Pictures for AI/Site 179/4 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 14/8 - Probable(weak sucker attachments at topping cuts).JPG',
#  '../../data/raw/Pictures for AI/Site 22/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 20/9, 10, 11, 12, 13, 14 - Improbable (all eastern red cedar 6 trees, numbered right to left).JPG',
#  '../../data/raw/Pictures for AI/Site 23/Improbable_4_london plane.JPG',
#  '../../data/raw/Pictures for AI/Site 82/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 113/8 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 182/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 161/Probable (dead overhangs, decay).JPG',
#  '../../data/raw/Pictures for AI/Site 116/Possible (low codominant union).JPG',
#  '../../data/raw/Pictures for AI/Site 182/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 178/Probable (dead hanging limb).JPG',
#  '../../data/raw/Pictures for AI/Site 72/Possible.JPG',
#  '../../data/raw/Pictures for AI/Site 82/Probable.JPG',
#  '../../data/raw/Pictures for AI/Site 70/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 6/Improbable_5.JPG',
#  '../../data/raw/Pictures for AI/Site 144/Probable (dead wood, dieback).jpg',
#  '../../data/raw/Pictures for AI/Site 10/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 14/3 - Probable(previously topped, weak attachments).JPG',
#  '../../data/raw/Pictures for AI/Site 15/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 40/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 10/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 9/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 70/Possible (wound and decay, trunk, street side).JPG',
#  '../../data/raw/Pictures for AI/Site 97/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 52/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 28/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 8/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 17/Possible (red maple, weak attachment angles).JPG',
#  '../../data/raw/Pictures for AI/Site 31/Improbable (acer platanoides).JPG',
#  '../../data/raw/Pictures for AI/Site 118/Probable (two left trees, decay and frass, partial failure on far left tree).JPG',
#  '../../data/raw/Pictures for AI/Site 49/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 113/11 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 97/Possible (crack at multi stem junction).JPG',
#  '../../data/raw/Pictures for AI/Site 66/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 73/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 9/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 22/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 20/2 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 67/Improbable 2.JPG',
#  '../../data/raw/Pictures for AI/Site 182/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 76/Possible.JPG',
#  '../../data/raw/Pictures for AI/Site 128/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 7/Possible (dead limb, weak attachment).JPG',
#  '../../data/raw/Pictures for AI/Site 148/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 118/Possible (low codominant junction).JPG',
#  '../../data/raw/Pictures for AI/Site 13/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 84/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 179/9 - Improbable (crabapple).JPG',
#  '../../data/raw/Pictures for AI/Site 152/Improbable (weeping cherry).JPG',
#  '../../data/raw/Pictures for AI/Site 25/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 25/Improbable_3.JPG',
#  '../../data/raw/Pictures for AI/Site 2/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 34/Possible (previous failure, reaction wood).JPG',
#  '../../data/raw/Pictures for AI/Site 149/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 28/Possible (poor attachment codominant stems, weeping pitch).JPG',
#  '../../data/raw/Pictures for AI/Site 84/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 76/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 1/Improbable 6.JPG',
#  '../../data/raw/Pictures for AI/Site 148/Possible (deadwood).JPG',
#  '../../data/raw/Pictures for AI/Site 161/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 47/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 161/Possible (verticle cracks on either side of trunk).JPG',
#  '../../data/raw/Pictures for AI/Site 8/Probable (dead top).JPG',
#  '../../data/raw/Pictures for AI/Site 2/Probable (Quercus coccinea, dead overhang at aprox 50 ft).JPG',
#  '../../data/raw/Pictures for AI/Site 11/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 178/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 41/Possible (Co-dom).JPG',
#  '../../data/raw/Pictures for AI/Site 148/probable (deadwood, weak attachments, decay).JPG',
#  '../../data/raw/Pictures for AI/Site 179/7 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 163/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 182/Improbable (touching primary lines).JPG',
#  '../../data/raw/Pictures for AI/Site 4/Probable(significant deadwood and decay).JPG',
#  '../../data/raw/Pictures for AI/Site 113/14 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 34/Possible (eastern white pine).JPG',
#  '../../data/raw/Pictures for AI/Site 28/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 104/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 97/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 148/Possible (trunk wound, decay).JPG',
#  '../../data/raw/Pictures for AI/Site 23/Improbable_5_london plane.JPG',
#  '../../data/raw/Pictures for AI/Site 46/4 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 1/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 155/Probable (deadwood, previous failures, red maple on right).JPG',
#  '../../data/raw/Pictures for AI/Site 112/Possible (dead overhang, no decay visible).JPG',
#  '../../data/raw/Pictures for AI/Site 10/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 113/9 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 104/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 113/3 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 148/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 51/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 34/Improbable (topped eastern white pine).JPG',
#  '../../data/raw/Pictures for AI/Site 111/Probable (decay, insect damage with frass, codominant stems, included bark).JPG',
#  '../../data/raw/Pictures for AI/Site 152/Improbable (maple).JPG',
#  '../../data/raw/Pictures for AI/Site 31/Improbable (small crimson king acer platanoides).JPG',
#  '../../data/raw/Pictures for AI/Site 95/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 6/Improbable_6.JPG',
#  '../../data/raw/Pictures for AI/Site 66/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 8/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 118/Possible (deadwood at line height).JPG',
#  '../../data/raw/Pictures for AI/Site 29/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 82/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 72/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 6/Improbable_3.JPG',
#  '../../data/raw/Pictures for AI/Site 81/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 17/Possible (silver maple, weak attachments, reaction wood present).JPG',
#  '../../data/raw/Pictures for AI/Site 42/Probable (standing dead).JPG',
#  '../../data/raw/Pictures for AI/Site 15/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 95/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 6/Improbable_8.JPG',
#  '../../data/raw/Pictures for AI/Site 22/Possible (dead limbs poor attachment).JPG',
#  '../../data/raw/Pictures for AI/Site 161/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 96/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 53/Possible (large defect rear of tree with decay, reaction wood).JPG',
#  '../../data/raw/Pictures for AI/Site 113/2 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 96/Possible (large decaying wound at base, reaction wood present).JPG',
#  '../../data/raw/Pictures for AI/Site 149/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 176/Improbable (hemlock 2).jpg',
#  '../../data/raw/Pictures for AI/Site 162/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 60/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 2/Improbable (pinus strobus), Possible (topped populus deltoides), improbable (pinus strobus).JPG',
#  '../../data/raw/Pictures for AI/Site 46/1- Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 29/Probable (deadwood above line height, vine covered).JPG',
#  '../../data/raw/Pictures for AI/Site 88/Improbable_2.JPG',
#  '../../data/raw/Pictures for AI/Site 72/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 98/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 73/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 113/12 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 52/Possible (weak attachments).JPG',
#  '../../data/raw/Pictures for AI/Site 9/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 178/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 61/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 42/Possible (weak attachment, lion tail).JPG',
#  '../../data/raw/Pictures for AI/Site 88/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 71/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 23/Probable (dead overhang).JPG',
#  '../../data/raw/Pictures for AI/Site 154/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 7/Possible (spruce, codominant and dieback).JPG',
#  '../../data/raw/Pictures for AI/Site 60/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 70/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 97/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 11/Possible.JPG',
#  '../../data/raw/Pictures for AI/Site 48/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 152/Improbable (atlas cedar).JPG',
#  '../../data/raw/Pictures for AI/Site 67/Possible (co-dom 3stem).JPG',
#  '../../data/raw/Pictures for AI/Site 54/Possible(crack rear side, bleeding).JPG',
#  '../../data/raw/Pictures for AI/Site 7/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 21/Possible.jpg',
#  '../../data/raw/Pictures for AI/Site 182/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 61/Improbable (liquidambar).JPG',
#  '../../data/raw/Pictures for AI/Site 182/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 46/2 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 113/10 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 28/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 167/Improbable (5).JPG',
#  '../../data/raw/Pictures for AI/Site 118/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 96/Possible (previous failure and decay above lines, reaction wood).JPG',
#  '../../data/raw/Pictures for AI/Site 167/Improbable (6).JPG',
#  '../../data/raw/Pictures for AI/Site 20/5 - Improbable (eastern red cedar).JPG',
#  '../../data/raw/Pictures for AI/Site 54/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 51/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 54/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 40/Improbable (4).JPG',
#  '../../data/raw/Pictures for AI/Site 22/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 98/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 28/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 53/Probable (decay, poor attachment angle, included bark).JPG',
#  '../../data/raw/Pictures for AI/Site 11/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 70/Improbable (3).JPG',
#  '../../data/raw/Pictures for AI/Site 70/Probable (large wound on trunk, loose bark, dieback, decay).JPG',
#  '../../data/raw/Pictures for AI/Site 54/Probable(vertical crack rear side of trunk, weak attachments).JPG',
#  '../../data/raw/Pictures for AI/Site 76/Improbable (2).JPG',
#  '../../data/raw/Pictures for AI/Site 20/1 - Probable (decay on low crotch, included bark).JPG',
#  '../../data/raw/Pictures for AI/Site 155/Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 179/8 - Possible (included bark, codominant multi stem, low crotch).JPG',
#  '../../data/raw/Pictures for AI/Site 2/Possible (trunk would opposite partially uncorrected lean).JPG',
#  '../../data/raw/Pictures for AI/Site 4/Possible (weak attachments, previous failure with epicormic growth).JPG',
#  '../../data/raw/Pictures for AI/Site 113/15 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 17/Possible (silver maple, codom weak attach, reaction wood).JPG',
#  '../../data/raw/Pictures for AI/Site 48/Possible (poor attachment, decay).JPG',
#  '../../data/raw/Pictures for AI/Site 113/13 - Improbable.JPG',
#  '../../data/raw/Pictures for AI/Site 34/Possible (eastern white pine, dead overhangs) (2).JPG',
#  '../../data/raw/Pictures for AI/Site 42/Possible (weak attachment angles).JPG',
#  '../../data/raw/Pictures for AI/Site 23/Improbable_3_london plane.JPG',
#  '../../data/raw/Pictures for AI/Site 116/Possible (deadwood in crown).JPG',
#  '../../data/raw/Pictures for AI/Site 20/11, 12, 13, 14 - Improbable (all eastern red cedar 4 trees).JPG',
#  '../../data/raw/Pictures for AI/Site 88/Probable_Lower limb failure.JPG']

# %%
IMG_SIZE = 300
DIR = '../../data/tidy/labeled_images'
def load_training_data():
    train_data = []
    image_list = os.listdir(DIR)
    training_image_list = random.sample(image_list, int(.9*len(image_list))) # take 90% of image data for traing
    for img in training_image_list:
        label = label_img(img)
        path = os.path.join(DIR, img)
        img = Image.open(path)
        img = img.convert('L') # convert image to monochrome - this works
        #img = img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
        train_data.append([np.array(img), label])    
    
#     # Basic Data Augmentation - Horizontal Flipping
#     flip_img = Image.open(path)
#     flip_img = flip_img.convert('L')
#     flip_img = flip_img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
#     flip_img = np.array(flip_img)
#     flip_img = np.fliplr(flip_img)
#     train_data.append([flip_img, label])  
#    shuffle(train_data)
  return train_data

# %%
train_data = load_training_data()
plt.imshow(train_data[43][0], cmap = 'gist_gray')

# %%
model = models.Sequential([
    layers.Conv2D(64, 7, activation="relu", padding="same", input_shape = [28, 28, 1 ]), #input shape of course needs to be changed
    layers.MaxPooling2D(2),
    layers.Conv2D(128, 3, activation="relu", padding="same"),
    layers.Conv2D(128, 3, activation="relu", padding="same"),
    layers.MaxPooling2D(2),
    layers.Conv2D(256, 3, activation="relu", padding="same"),
    layers.Conv2D(256, 3, activation="relu", padding="same"),
    layers.MaxPooling2D(2),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(64, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(10, activation="softmax")
])
