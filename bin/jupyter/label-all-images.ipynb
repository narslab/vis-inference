# %%
import pandas as pd
from PIL import Image # used for loading images 
import numpy as np
import os # used for navigating to image path
import imageio # used for writing images
import natsort
from natsort import natsorted
import re # for matching image file name classes
import matplotlib.pyplot as plt
import random
import ntpath
import shutil
import csv
from timeit import default_timer as timer
import platform

# %%
RAW_IMAGE_DIR = '../../data/raw/Pictures for AI'
RAW_IMAGE_DIR_SUMMER = '../../data/raw/Summer 2021 AI Photos'
RAW_IMAGE_DIR_FALL = '../../data/raw/Likelihood of Failure Images/'
TIDY_IMAGE_TEST_DIR = '../../data/tidy/labeled-images-test/'
TIDY_IMAGE_DIR = '../../data/tidy/labeled-images/'
INDEX_DIR = '../../results/index-raw/'
INDEX_TEST_DIR = '../../results/index-raw-test/'
TRIM_LIST = RAW_IMAGE_DIR_FALL+'likelihood.csv'
NO_TRAILING = RAW_IMAGE_DIR_FALL+'Likelihood_of_failure_no_trailing.csv'

# %%
def getListOfFiles(dirName):
    """Returns single list of the filepath of each of the image files"""
    # source: https://thispointer.com/python-how-to-get-list-of-files-in-directory-and-sub-directories/
    allFiles = list()
    if 'Pictures for AI' or 'Likelihood of Failure Images' in dirName: # 
        listOfFile = os.listdir(dirName)
        # Iterate over all the entries
        for entry in listOfFile:
            # Create full path
            fullPath = os.path.join(dirName, entry)
            # If entry is a directory then get the list of files in this directory 
            if os.path.isdir(fullPath):
                allFiles = allFiles + getListOfFiles(fullPath)
            else:
                allFiles.append(fullPath)
    else:
        level_one = [f.path for f in os.scandir(dirName) if f.is_dir()] # get all of the immediate subdirectories in the parent folder downloaded from SharePoint
        for subdir in level_one:
            level_two = [f.path for f in os.scandir(subdir) if f.is_dir()] # get all of the immediate subdirectories for each arborist
            print(level_two)
            for subdir2 in level_two:
                if ('Away' in subdir2): # do not include images taken away powerlines
                    print('Ignoring images away from power lines')
                    #break
                else:
                    listOfFile = os.listdir(subdir2) # retain only images taken near power lines
                    # Iterate over all the entries
                    for entry in listOfFile:
                        # Create full path
                        fullPath = os.path.join(subdir2, entry)
                        # If entry is a directory then get the list of files in this directory 
                        if os.path.isdir(fullPath):
                            allFiles = allFiles + getListOfFiles(fullPath)
                        else:
                            allFiles.append(fullPath)
    return allFiles

# %%
def splitIndexDescrArb(images):
    """Split the filepaths of the images taken in Summer 2021 a list of indices, descriptions and arborists"""
    index_list = []
    description_list = []
    arborist_list = []
    for fn in images:
        print('fn: ' + fn)
        if (platform.system() == 'Windows'):
            if ('_' in fn):
                index = fn.split('_')[0].split('\\')[-1]
                description = fn.split('_')[1]
                arborist = fn.split('_')[0].split('\\')[1].split('/')[-1]
            else:
                index = fn.split('-')[0].split('\\')[-1].rstrip(' ')
                description = fn.split('-')[1]
                arborist = fn.split('-')[0].split('\\')[1].split('/')[-1]        
        else: #Unix/Linux systems
            if ('_' in fn):
                index = fn.split('_')[0].split('/')[-1]
                print("Index" + index)
                description = fn.split('_')[1]
                arborist = fn.split('_')[0].split('/')[-3] #.split('/')[-2]
                print(arborist)
            else:
                index = fn.split('-')[0].split('/')[-1].rstrip(' ')
                description = fn.split('-')[1]
                arborist = fn.split('-')[0].split('/')[-3]                    
        index = int(index)
        index_list.append(index)
        description_list.append(description)
        arborist_list.append(arborist)
    return index_list, description_list, arborist_list

# %%
def getUniqueImages(images, arb_list, idx_label, descr):
    """Get a list of unique Summer 2021 images by ignoring close-ups. Only selects an image with the classification present in the label."""
    df = pd.DataFrame([images, arb_list, idx_label, descr])
    df = df.transpose()
    df.columns=['Filename','Arborist', 'Index_Label', 'Description']
    unique_image_list = []
    for arborist in df.Arborist.unique():
        print(arborist)
        dfsub = df.loc[df.Arborist == arborist]
        for index in dfsub.Index_Label.unique():
            dfsub2 = dfsub.loc[dfsub.Index_Label == index]
            if len(dfsub2) == 1:
                selected_filename = dfsub2.Filename.tolist()[0]
            else:
                good_index_list = []
                for r in dfsub2.index:
                    if 'closeup' not in dfsub2.loc[r, 'Description']:
                        l = ['probable', 'possible', 'improbable']
                        if [i for i in l if re.findall(i, dfsub2.loc[r, 'Description'], re.IGNORECASE)]: # check if a classification is included in the file name
                            good_index_list.append(r)
                print(good_index_list)
                if len(good_index_list) == 1:
                    selected_filename = dfsub2.loc[good_index_list, 'Filename'].tolist()[0]
                else:
                    testdf = dfsub2.loc[good_index_list]
                    testdf['DescriptionLength'] = testdf.Description.str.len()
                    for i in good_index_list:
                        selected_filename = testdf.loc[testdf.DescriptionLength.idxmin(), 'Filename']
            print(selected_filename)                
            unique_image_list.append(selected_filename)
    return unique_image_list

# %%
def trimTrailingChars(data):
    """Converts original excel file containing classification categories for Fall 2021 images to csv"""
    read_file = pd.read_excel(data)
    read_file.to_csv(TRIM_LIST, index = None, header=True)
    read_file = pd.read_csv(TRIM_LIST)
    read_file['Likelihood of Failure Rating'] = read_file['Likelihood of Failure Rating'].str.replace('\xa0','')
    df = read_file.rename({"Image":"image", "File Name":"file_name", "Likelihood of Failure Rating": "likelihood_of_failure_rating"}, axis='columns')
    df.to_csv(NO_TRAILING, index = None, header=True)
    print(df.head())
    print(df['likelihood_of_failure_rating'].unique())
    if os.path.isfile(TRIM_LIST):
        os.remove(TRIM_LIST)

# %%
def encrypt(file_name):
    """Cryptographically encrypts each failure likelihood category using Python's built-in hash function"""
    if any(re.findall(r'improbable', file_name, re.IGNORECASE)):
        h = hash('improbable')
    elif any(re.findall(r'probable', file_name, re.IGNORECASE)):
        h = hash('probable')
    elif any(re.findall(r'possible', file_name, re.IGNORECASE)):
        h = hash('possible')
    else:
        h = hash('unknown')
    return h

# %%
def updateNameCount(word, d):
    """Creates a uniform label for all saved images and updates the global count"""
    h  = encrypt(word)
    save_name = ''
    for key in d.keys():
        if h == hash(key):
            save_name = TIDY_IMAGE_TEST_DIR + key + '-' + str(d[key]) + '.jpg'
            d[key] += 1
    return save_name

# %%
def saveImageFiles(image_file_list):
    """Serially labels all images by class:  and saves them to the designated tidy image directory."""
    counts = {'improbable':1,
                'possible':1,
                'probable':1,
                'unknown':1}
    csv_col_index = ['Labeled Image', 'Original File Path']
    index = {}
    shutil.rmtree(TIDY_IMAGE_TEST_DIR, ignore_errors=True) # Deletes the directory containing any existing labeled images
    shutil.rmtree(INDEX_TEST_DIR, ignore_errors=True)
    if not os.path.exists(TIDY_IMAGE_TEST_DIR):
        os.makedirs(TIDY_IMAGE_TEST_DIR)
    for filename in image_file_list:
        if '.JPG'.casefold() in filename.casefold():
            save_name = updateNameCount(filename, counts)
            imageio.imwrite(save_name, np.array(Image.open(filename)))
            index[save_name] = filename
        if '.HEIC'.casefold() in filename.casefold():
            df = pd.read_csv(NO_TRAILING)
            for row in df.itertuples():
                image_name = row.file_name
                rating = row.likelihood_of_failure_rating
                if image_name == filename.split("Failure Images/",1)[1]:
                    save_name = updateNameCount(rating, counts)
                    shutil.copy2(filename, save_name)
                    continue                    
            index[save_name] = filename
    if not os.path.exists(INDEX_TEST_DIR):
        os.makedirs(INDEX_TEST_DIR)
    with open(INDEX_TEST_DIR + 'labels_index.csv', 'w', newline='') as f: # TODO: separate by tab not comma
        writer = csv.DictWriter(f, fieldnames=csv_col_index)
        writer.writeheader()
        for key in natsort.natsorted(index.keys()): # iterate through the alphanumeric keys in a natural order
            key_name = key.replace(TIDY_IMAGE_TEST_DIR,'')
            val_name = index[key]
            f.write("%s,%s\n"%(key_name,val_name))
    
    print('Number of improbable images:', counts['improbable']-1)    
    print('Number of possible images:', counts['possible']-1)
    print('Number of probable images:', counts['probable']-1)
    print('Number of unknown images:', counts['unknown']-1)
    print('Total number of classified images:', counts['improbable']+counts['possible']+counts['probable']-3)

# %%
### PREVIOUS IMPLEMENTATION
def saveImageFiles(image_file_list): 
    """Serially labels all images by class:  and saves them to the designated tidy image directory."""
    
    improbable_counter = 1
    possible_counter = 1
    probable_counter = 1
    if not os.path.exists(TIDY_IMAGE_DIR):
        os.makedirs(TIDY_IMAGE_DIR)
    for filename in image_file_list:
        if '.JPG' in filename or '.jpg' in filename:        
            if any(re.findall(r'improbable', filename, re.IGNORECASE)):
                save_name = TIDY_IMAGE_DIR + 'improbable' + '-' + str(improbable_counter) + '.jpg'
                improbable_counter += 1
            elif any(re.findall(r'probable', filename, re.IGNORECASE)):
                save_name = TIDY_IMAGE_DIR + 'probable' + '-' + str(probable_counter) + '.jpg'
                probable_counter += 1 
            elif any(re.findall(r'possible', filename, re.IGNORECASE)):
                save_name = TIDY_IMAGE_DIR + 'possible' + '-' + str(possible_counter) + '.jpg'
                possible_counter += 1 
            imageio.imwrite(save_name, np.array(Image.open(filename)))
    print('Number of improbable images saved:', improbable_counter - 1)    
    print('Number of possible images saved:', possible_counter - 1)
    print('Number of probable images saved:', probable_counter - 1)

# %%
trimTrailingChars(RAW_IMAGE_DIR_FALL+'Likelihood of Failure Images.xlsx')
original_photos = getListOfFiles(RAW_IMAGE_DIR)
summer_photos = getListOfFiles(RAW_IMAGE_DIR_SUMMER)
fall_photos = getListOfFiles(RAW_IMAGE_DIR_FALL)
index_list, description_list, arborist_list = splitIndexDescrArb(summer_photos)
unique_image_list_summer = getUniqueImages(summer_photos, arborist_list, index_list, description_list)
# Out:
#    image      file_name likelihood_of_failure_rating
# 0  936.0  IMG_0936.HEIC                     Possible
# 1  937.0  IMG_0937.HEIC                     Probable
# 2  938.0  IMG_0938.HEIC                     Probable
# 3  939.0  IMG_0939.HEIC                   Improbable
# 4  940.0  IMG_0940.HEIC                   Improbable
# ['Possible' 'Probable' 'Improbable' 'probable' '2 improbable'
#  'Improbable (catalpa)' 'Imminent'
#  'From left to right: Improbable, Possible'
#  'From left to right: improbable, probable, imminent' '2 probable'
#  'Imminent (same as IMG_1134.HEIC)' nan]
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\15_probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\15_probable_crack.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\16_possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\17_improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\18_possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\18_possible_codominant_stems.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\19_improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\1_possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\1_possible_dead_branch.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\20_possible_decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\20_possible_decay2.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\21_probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\29_possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\29_possible_codominant_stems.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\2_improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\30_improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\31_improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\32_possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\32_possible_codominant_stems.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\33_hidden_defect.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\33_improbable_because_limited_visual.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\36_improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\37_probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\37_probable_dead_branch.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\38_improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\39_probable_dead.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\40_probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\40_probable_decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\41_possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\41_possible_decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\1 - Probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\10 - Probable - dead branches closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\10 - Probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\11 - improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\12 - improbable - reaction wood around codominant stem.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\12 - improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\13 - improbable - branch union closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\13 - improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\14 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\15 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\16 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\17 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\18 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\19 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\2 - Probable - codominant stem closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\2 - Probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\20 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\21 - improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\22- Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\23 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\24 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\25 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\26 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\27 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\28 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\29 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\3 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\30 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\31- Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\32 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\33 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\34 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\35 - Probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\36 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\37 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\38 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\39 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\4 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\40 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\41 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\42 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\43 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\44 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\45 - Possible - Close up, included bark.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\45 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\46 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\47 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\48 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\49 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\5 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\50 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\51 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\52 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\53 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\54 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\55 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\56 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\57 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\58 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\59 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\6 - Probable - crack in codominant stem closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\6 - Probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\60 - Probable - close up, dead branch.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\60 - Probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\61 - Probable - close up, dead branch.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\61 - Probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\62 - improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\63 - possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\64 - possible - close up, crack in codominant stem.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\64 - possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\65 - improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\66 - improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\7 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\8 - Improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\9 - Possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\1-possible-codominant.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\1-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\10-improbable-closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\10-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\11-possible-codominant with included bark.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\11-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\12-possible-crack closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\12-possible-crack.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\12-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\13-probable-crack closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\13-probable-crack with decay and insects.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\13-probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\14-improbable-closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\14-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\14-probable-cracks decay loose bark weak attachment angles.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\14-probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\15-possible-crack closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\15-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\16-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\17-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\18-possible-dieback closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\19-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\2-improbable-closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\2-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\3-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\4-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\5-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\6-probable-fruiting body.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\6-probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\7-improbable-closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\7-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\8-improbable-closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\8-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\9-possible-codominant with reaction wood.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\9-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\1-improbable-closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\1-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\10-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\100-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\101-probable significant deadwood and decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\102-probable deadwood closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\103-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\104-possible codominant stem.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\105-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\106-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\107-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\108-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\109-codominant closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\109-possible low codominant union.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\11-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\110-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\111-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\112-possible union closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\112-possible weak attachment on low branch.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\113-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\114-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\115-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\116-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\117-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\118-possible closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\118-possible codominant with included bark.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\119-possible hollow next to weak branch union.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\119-possible-closeup of union and branch decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\12-possible closeup dead limb.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\12-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\120-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\121-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\13-possible codominant with included bark.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\13-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\14-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\15-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\16-possible closeup codomindant.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\16-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\17-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\18-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\19-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\2-improbable closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\2-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\20-dieback closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\20-possible dieback.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\21-probable closeup dead branch.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\21-probable dead cracked branch.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\22-probable closeup previous failure.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\22-probable previous failure and dead branches.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\23- possible dieback closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\23-possible dieback.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\24-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\25-improbable reaction wood closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\25-improbable reaction wood.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\26-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\27-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\28-possible dieback closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\28-possible dieback.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\29-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\3-possible closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\3-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\30-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\31-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\32-probable cavity closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\32-probable dead limb closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\32-probable large cavities dead limbs.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\33-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\34-probable failure would closeup 2.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\34-probable failure wound closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\34-probable large previous failure wound.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\35-possible low crotch codominant.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\36-possible crown dieback.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\37-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\38-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\39-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\4- probable closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\4-probable (1).jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\4-probable closeup weak union with decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\4-probable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\40-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\41-possible crown dieback.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\42-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\43-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\44-possible basal wound closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\44-possible crown dieback and basal wound.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\44-possible crown dieback closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\45-possible codominant closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\45-possible codominant.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\46-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\47-possible large past failure.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\47-possible past failure closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\48-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\49-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\5-possible codominant closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\5-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\50-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\51-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\52-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\53-improbable codominant massive response growth.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\53-improbable response growth closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\54-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\55-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\56-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\57-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\58-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\59-possible codominant union.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\6-possible closeup root decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\6-possible trunk decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\6-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\60-possible codominant union closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\61-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\62-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\63-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\64-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\65-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\66-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\67-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\68-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\69-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\7- possible closeup root wounds.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\7-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\70-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\71-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\72-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\73-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\74-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\75-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\76-possible codominant stem with crack and reaction wood.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\76-possible union closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\77-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\78-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\79-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\8-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\80-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\81-possible crown dieback closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\81-possible crown dieback.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\82-possible codominant closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\82-possible codominant stems included bark.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\83-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\84-possible failure wound closeup 2.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\84-possible failure wound closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\84-possible previous failure and decay.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\85-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\86-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\87-possible cracked codominant closeup 2.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\87-possible cracked codominant closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\87-possible cracked codominant stem.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\88-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\89-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\9-possible closeup crack.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\9-possible.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\90-possible weak union with reaction wood closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\90-possible weak unions and reaction wood.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\91-probable basal wound closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\91-probable dead section closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\91-probable-large dead sections and basal wound with loose bark.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\92-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\93-improbable closeup 2.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\93-improbable codominant stem with reaction wood.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\93-improbable reaction wood closeup.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\94-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\95-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\96-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\97-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\98-improbable.jpg
# fn: ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\99-improbable.jpg
# Amanda
# [0, 1]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\15_probable_crack.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\16_possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\17_improbable.jpg
# [4, 5]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\18_possible_codominant_stems.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\19_improbable.jpg
# [7, 8]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\1_possible_dead_branch.jpg
# [9, 10]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\20_possible_decay.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\21_probable.jpg
# [12, 13]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\29_possible_codominant_stems.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\2_improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\30_improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\31_improbable.jpg
# [17, 18]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\32_possible_codominant_stems.jpg
# [20]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\33_improbable_because_limited_visual.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\36_improbable.jpg
# [22, 23]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\37_probable_dead_branch.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\38_improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\39_probable_dead.jpg
# [26, 27]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\40_probable_decay.jpg
# [28, 29]
# ../../data/raw/Summer 2021 AI Photos\Amanda\Near power lines\41_possible_decay.jpg
# Ari
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\1 - Probable.jpg
# [31, 32]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\10 - Probable - dead branches closeup.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\11 - improbable.jpg
# [34, 35]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\12 - improbable - reaction wood around codominant stem.jpg
# [36, 37]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\13 - improbable - branch union closeup.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\14 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\15 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\16 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\17 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\18 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\19 - Improbable.jpg
# [44, 45]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\2 - Probable - codominant stem closeup.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\20 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\21 - improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\22- Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\23 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\24 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\25 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\26 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\27 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\28 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\29 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\3 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\30 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\31- Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\32 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\33 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\34 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\35 - Probable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\36 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\37 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\38 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\39 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\4 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\40 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\41 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\42 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\43 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\44 - Improbable.jpg
# [73, 74]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\45 - Possible - Close up, included bark.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\46 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\47 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\48 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\49 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\5 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\50 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\51 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\52 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\53 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\54 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\55 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\56 - Possible.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\57 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\58 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\59 - Improbable.jpg
# [90, 91]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\6 - Probable - crack in codominant stem closeup.jpg
# [92, 93]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\60 - Probable - close up, dead branch.jpg
# [94, 95]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\61 - Probable - close up, dead branch.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\62 - improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\63 - possible.jpg
# [98, 99]
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\64 - possible - close up, crack in codominant stem.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\65 - improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\66 - improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\7 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\8 - Improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ari\Near power lines\9 - Possible.jpg
# Ryan
# [105, 106, 140, 141]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\1-possible-codominant.jpg
# [107, 108, 142]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\10-improbable-closeup.jpg
# [109, 110, 154]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\11-possible-codominant with included bark.jpg
# [111, 112, 113, 169]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\12-possible-crack closeup.jpg
# [114, 115, 116, 172, 173]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\13-probable-crack closeup.jpg
# [117, 118, 119, 120, 174]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\14-probable-cracks decay loose bark weak attachment angles.jpg
# [121, 122, 175]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\15-possible-crack closeup.jpg
# [123, 177]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\16-possible.jpg
# [124, 178]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\17-possible.jpg
# [125, 179]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\18-possible-dieback closeup.jpg
# [126, 180]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\19-improbable.jpg
# [127, 128, 182]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\2-improbable-closeup.jpg
# [129, 200]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\3-possible.jpg
# [130, 216, 218]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\4-possible.jpg
# [131, 234]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\5-possible.jpg
# [132, 133, 247, 248]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\6-probable-fruiting body.jpg
# [134, 135, 260]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\7-improbable-closeup.jpg
# [136, 137, 272]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\8-improbable-closeup.jpg
# [138, 139, 290]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Away from power lines\9-possible-codominant with reaction wood.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\100-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\101-probable significant deadwood and decay.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\102-probable deadwood closeup.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\103-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\104-possible codominant stem.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\105-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\106-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\107-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\108-improbable.jpg
# [153]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\109-possible low codominant union.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\110-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\111-improbable.jpg
# [158]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\112-possible weak attachment on low branch.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\113-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\114-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\115-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\116-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\117-improbable.jpg
# [165]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\118-possible codominant with included bark.jpg
# [166, 167]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\119-possible-closeup of union and branch decay.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\120-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\121-improbable.jpg
# [184]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\20-possible dieback.jpg
# [186]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\21-probable dead cracked branch.jpg
# [188]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\22-probable previous failure and dead branches.jpg
# [190]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\23-possible dieback.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\24-improbable.jpg
# [193]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\25-improbable reaction wood.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\26-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\27-improbable.jpg
# [197]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\28-possible dieback.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\29-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\30-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\31-improbable.jpg
# [205]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\32-probable large cavities dead limbs.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\33-improbable.jpg
# [209]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\34-probable large previous failure wound.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\35-possible low crotch codominant.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\36-possible crown dieback.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\37-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\38-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\39-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\40-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\41-possible crown dieback.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\42-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\43-improbable.jpg
# [224]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\44-possible crown dieback and basal wound.jpg
# [227]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\45-possible codominant.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\46-improbable.jpg
# [229]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\47-possible large past failure.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\48-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\49-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\50-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\51-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\52-improbable.jpg
# [238]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\53-improbable codominant massive response growth.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\54-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\55-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\56-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\57-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\58-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\59-possible codominant union.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\60-possible codominant union closeup.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\61-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\62-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\63-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\64-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\65-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\66-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\67-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\68-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\69-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\70-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\71-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\72-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\73-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\74-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\75-improbable.jpg
# [267]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\76-possible codominant stem with crack and reaction wood.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\77-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\78-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\79-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\80-improbable.jpg
# [275]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\81-possible crown dieback.jpg
# [277]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\82-possible codominant stems included bark.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\83-improbable.jpg
# [281]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\84-possible previous failure and decay.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\85-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\86-improbable.jpg
# [286]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\87-possible cracked codominant stem.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\88-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\89-improbable.jpg
# [292]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\90-possible weak unions and reaction wood.jpg
# [295]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\91-probable-large dead sections and basal wound with loose bark.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\92-improbable.jpg
# [298]
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\93-improbable codominant stem with reaction wood.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\94-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\95-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\96-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\97-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\98-improbable.jpg
# ../../data/raw/Summer 2021 AI Photos\Ryan\Near power lines\99-improbable.jpg

# %%
saveImageFiles(original_photos+unique_image_list_summer+fall_photos)
# Out:
# Number of improbable images: 515
# Number of possible images: 178
# Number of probable images: 155
# Number of unknown images: 40
# Total number of classified images: 848
