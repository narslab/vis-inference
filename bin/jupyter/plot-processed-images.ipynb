# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#imd252 = np.load('../../data/tidy/preprocessed-images/testing-w-252px-h-252px-scenario-Pr_Po_Im-train.npy',allow_pickle = True)
imd252b = np.load('../../data/tidy/preprocessed-images/w-252px-h-252px-scenario-Pr_Po_Im-train.npy',allow_pickle = True)
#imd64 = np.load('../../data/tidy/preprocessed_images/size64_exp5_Pr_Po_Im.npy',allow_pickle = True)

# %%
np.shape(imd252)
# Out:
# (16, 2)

# %%
## imd252[4][1]
plt.figure()
plt.imshow(np.fliplr(np.rot90((imd252[3][0]))), cmap = 'gist_gray', ) #retain only odd-numbered indices for paper (plot-processed-images.py)
plt.tight_layout()

# plt.figure()
# plt.imshow(np.fliplr(imd252[158][0]), cmap = 'gist_gray', ) #retain only odd-numbered indices for paper
#plt.imshow(np.flipud(imd252[158][0]), cmap = 'gist_gray', ) #retain only odd-numbered indices for paper
# plt.tight_layout()
#plt.savefig('../../figures/processed-image-128px-260.png',bbox_inches='tight')#, dpi=180)

# %%
plt.figure()
plt.imshow(imd252b[3][0], cmap = 'gist_gray', ) #retain only odd-numbered indices for paper (plot-processed-images.py)
plt.tight_layout()

# %%
#imd64[21][1]
plt.imshow(imd64[264][0], cmap = 'gist_gray')#, interpolation='antialiased')
plt.tight_layout()
plt.savefig('../../figures/processed-image-64px-264.png',bbox_inches='tight')#, dpi=180)

# %%
:rc:savefig.dpi
# Out:
#   File "<ipython-input-29-52c78ad20bfa>", line 1
#     :rc:savefig.dpi
#     ^
# SyntaxError: invalid syntax
